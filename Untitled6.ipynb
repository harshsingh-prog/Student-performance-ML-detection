# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset = pd.read_excel("SchoolWise_Comparison (5).xlsx")

# %%
dataset
# Out:
#      Academic_Year    UdiseCode  \
# 0          2022-23  23320400102
# 1          2022-23  23320400105
# 2          2022-23  23320400106
# 3          2022-23  23320400107
# 4          2022-23  23320400108
# ...            ...          ...
# 1117       2022-23  23320404802
# 1118       2022-23  23320404803
# 1119       2022-23  23320404804
# 1120       2022-23  23320404805
# 1121       2022-23  23320404806
#
#                                              SchoolName  \
# 0                                    GOVT MS KHANU GAON
# 1     PVT MS (1-8) ANJORA MIDDLE SCHOOL, KHANUGAON (...
# 2     MADARSA (RE) PS (1-5) NEW HINA DEENI KHANUGAON...
# 3     MADARSA (RE) PS (1-5) AL NISA,HAMEEDULLAH NAGA...
# 4     MADARSA (RE) MS (1-8) TAYYAB,8-NOOR-US-SABHA R...
# ...                                                 ...
# 1117  PVT MS (1-8) VASANT VALLEY SCHOOL, NEAR GOVT H...
# 1118  PVT MS (1-8) VISHWAKARMA PUBLIC SCHOOL 75, PRE...
# 1119  PVT MS (1-8) JAY PRAKASH PUBLIC SCHOOL, HOUSE ...
# ...

# %%
dataset.head()
# Out:
#   Academic_Year    UdiseCode  \
# 0       2022-23  23320400102
# 1       2022-23  23320400105
# 2       2022-23  23320400106
# 3       2022-23  23320400107
# 4       2022-23  23320400108
#
#                                           SchoolName  \
# 0                                 GOVT MS KHANU GAON
# 1  PVT MS (1-8) ANJORA MIDDLE SCHOOL, KHANUGAON (...
# 2  MADARSA (RE) PS (1-5) NEW HINA DEENI KHANUGAON...
# 3  MADARSA (RE) PS (1-5) AL NISA,HAMEEDULLAH NAGA...
# 4  MADARSA (RE) MS (1-8) TAYYAB,8-NOOR-US-SABHA R...
#
#                  SchoolManagement                  SchoolCategory  BlockCode  \
# 0       1-Department of Education  2 - Primary with Upper Primary     233204
# 1  5-Private Unaided (Recognized)  2 - Primary with Upper Primary     233204
# 2           97-Madarsa recognized                     1 - Primary     233204
# 3           97-Madarsa recognized                     1 - Primary     233204
# ...

# %%
dataset.shape
# Out:
# (1122, 25)

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of      Academic_Year    UdiseCode  \
# 0          2022-23  23320400102
# 1          2022-23  23320400105
# 2          2022-23  23320400106
# 3          2022-23  23320400107
# 4          2022-23  23320400108
# ...            ...          ...
# 1117       2022-23  23320404802
# 1118       2022-23  23320404803
# 1119       2022-23  23320404804
# 1120       2022-23  23320404805
# 1121       2022-23  23320404806
#
#                                              SchoolName  \
# 0                                    GOVT MS KHANU GAON
# 1     PVT MS (1-8) ANJORA MIDDLE SCHOOL, KHANUGAON (...
# 2     MADARSA (RE) PS (1-5) NEW HINA DEENI KHANUGAON...
# 3     MADARSA (RE) PS (1-5) AL NISA,HAMEEDULLAH NAGA...
# 4     MADARSA (RE) MS (1-8) TAYYAB,8-NOOR-US-SABHA R...
# ...                                                 ...
# 1117  PVT MS (1-8) VASANT VALLEY SCHOOL, NEAR GOVT H...
# 1118  PVT MS (1-8) VISHWAKARMA PUBLIC SCHOOL 75, PRE...
# ...

# %%
dataset.describe()
# Out:
#           UdiseCode  BlockCode  ClassRoom_Tot_PY  ClassRoom_Tot_CY  \
# count  1.122000e+03     1122.0       1098.000000       1122.000000
# mean   2.332040e+10   233204.0         10.132058          9.620321
# std    1.200511e+03        0.0          8.387920          8.898789
# min    2.332040e+10   233204.0          0.000000          0.000000
# 25%    2.332040e+10   233204.0          4.000000          4.000000
# 50%    2.332040e+10   233204.0          8.000000          8.000000
# 75%    2.332040e+10   233204.0         13.000000         13.000000
# max    2.332040e+10   233204.0         70.000000         95.000000
#
#        Toilet_Boys_PY  Toilet_Boys_CY  Toilet_Girls_PY  Toilet_Girls_CY  \
# count     1098.000000     1122.000000      1098.000000      1122.000000
# mean         2.134791        2.162210         2.305100         2.273619
# std          2.317161        2.555796         4.409196         4.400855
# min          0.000000        0.000000         0.000000         0.000000
# ...

# %%
sns.countplot(x="SchoolName",data = dataset)
# Out:
# <Axes: xlabel='SchoolName', ylabel='count'>

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1122 entries, 0 to 1121
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Academic_Year          1122 non-null   object
#  1   UdiseCode              1122 non-null   int64
#  2   SchoolName             1122 non-null   object
#  3   SchoolManagement       1122 non-null   object
#  4   SchoolCategory         1122 non-null   object
#  5   BlockCode              1122 non-null   int64
#  6   SchoolType             1122 non-null   object
#  7   ClassRoom_Tot_PY       1098 non-null   float64
#  8   ClassRoom_Tot_CY       1122 non-null   int64
#  9   Toilet_Boys_PY         1098 non-null   float64
#  10  Toilet_Boys_CY         1122 non-null   int64
#  11  Toilet_Girls_PY        1098 non-null   float64
#  12  Toilet_Girls_CY        1122 non-null   int64
#  13  ToiletFunc_Boys_PY     1098 non-null   float64
# ...

# %%
dataset.describe().T
# Out:
#                       count          mean          std           min  \
# UdiseCode            1122.0  2.332040e+10  1200.511003  2.332040e+10
# BlockCode            1122.0  2.332040e+05     0.000000  2.332040e+05
# ClassRoom_Tot_PY     1098.0  1.013206e+01     8.387920  0.000000e+00
# ClassRoom_Tot_CY     1122.0  9.620321e+00     8.898789  0.000000e+00
# Toilet_Boys_PY       1098.0  2.134791e+00     2.317161  0.000000e+00
# Toilet_Boys_CY       1122.0  2.162210e+00     2.555796  0.000000e+00
# Toilet_Girls_PY      1098.0  2.305100e+00     4.409196  0.000000e+00
# Toilet_Girls_CY      1122.0  2.273619e+00     4.400855  0.000000e+00
# ToiletFunc_Boys_PY   1098.0  2.066485e+00     2.327386  0.000000e+00
# ToiletFunc_Boys_CY   1122.0  1.965241e+00     2.552507  0.000000e+00
# ToiletFunc_Girls_PY  1098.0  2.224954e+00     4.369180  0.000000e+00
# ToiletFunc_Girls_CY  1122.0  2.078431e+00     4.409573  0.000000e+00
# Teacher_Tot_PY       1098.0  9.257741e+00     8.482921  0.000000e+00
# ...

# %%
# !pip install missingno

# %%
import missingno as msno

# %%
msno.matrix(dataset)
# Out:
# <Axes: >

# %%
dataset['ClassRoom_Tot_PY'].value_counts()
# Out:
# ClassRoom_Tot_PY
# 8.0     126
# 4.0     105
# 3.0     102
# 5.0      93
# 11.0     84
# 2.0      64
# 10.0     59
# 12.0     52
# 6.0      42
# 13.0     36
# 14.0     32
# 15.0     32
# 7.0      31
# 9.0      28
# 16.0     26
# 17.0     20
# 1.0      19
# 18.0     15
# 19.0     12
# 25.0     12
# 20.0     12
# 22.0      9
# 24.0      8
# 21.0      8
# 23.0      8
# 0.0       8
# 30.0      7
# 34.0      4
# 29.0      4
# 28.0      4
# 26.0      4
# 33.0      3
# 32.0      3
# 35.0      3
# 42.0      3
# 36.0      3
# 27.0      3
# 49.0      2
# 60.0      1
# 50.0      1
# 40.0      1
# 31.0      1
# 54.0      1
# 70.0      1
# 65.0      1
# 41.0      1
# 38.0      1
# 59.0      1
# 45.0      1
# 44.0      1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.subplots(figsize=(15,5))
dataset['ClassRoom_Tot_PY'].value_counts(normalize = True)
dataset['ClassRoom_Tot_PY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['ClassRoom_Tot_CY'].value_counts()
# Out:
# ClassRoom_Tot_CY
# 11    122
# 0     120
# 8      99
# 4      94
# 3      83
# 2      69
# 5      61
# 13     45
# 12     45
# 15     45
# 10     40
# 14     35
# 6      30
# 9      28
# 7      26
# 17     26
# 18     15
# 20     14
# 16     14
# 25     14
# 19     12
# 22     10
# 24      9
# 1       8
# 23      7
# 29      6
# 28      4
# 21      4
# 30      4
# 40      3
# 26      3
# 36      3
# 27      3
# 49      2
# 38      2
# 42      2
# 32      2
# 45      1
# 34      1
# 95      1
# 59      1
# 41      1
# 55      1
# 63      1
# 60      1
# 58      1
# 43      1
# 50      1
# 33      1
# 54      1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['ClassRoom_Tot_CY'].value_counts(normalize = True)
dataset['ClassRoom_Tot_CY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['Toilet_Boys_PY'].value_counts()
# Out:
# Toilet_Boys_PY
# 1.0     538
# 2.0     291
# 3.0     100
# 4.0      55
# 0.0      26
# 6.0      24
# 5.0      23
# 10.0     10
# 7.0      10
# 8.0       9
# 12.0      5
# 14.0      2
# 15.0      1
# 18.0      1
# 27.0      1
# 26.0      1
# 29.0      1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['Toilet_Boys_PY'].value_counts(normalize = True)
dataset['Toilet_Boys_PY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['Toilet_Boys_CY'].value_counts()
# Out:
# Toilet_Boys_CY
# 1     488
# 2     268
# 3     121
# 0      90
# 4      64
# 5      23
# 6      21
# 7      11
# 12      9
# 10      7
# 8       6
# 15      3
# 9       2
# 11      2
# 20      2
# 18      1
# 14      1
# 27      1
# 26      1
# 29      1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['Toilet_Boys_CY'].value_counts(normalize = True)
dataset['Toilet_Boys_CY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['Toilet_Girls_PY'].value_counts()
# Out:
# Toilet_Girls_PY
# 1.0      552
# 2.0      286
# 3.0       85
# 4.0       75
# 5.0       23
# 6.0       16
# 0.0       15
# 10.0      11
# 8.0        9
# 7.0        8
# 12.0       5
# 14.0       3
# 18.0       2
# 26.0       1
# 27.0       1
# 23.0       1
# 123.0      1
# 11.0       1
# 24.0       1
# 9.0        1
# 22.0       1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['Toilet_Girls_PY'].value_counts(normalize = True)
dataset['Toilet_Girls_PY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['Toilet_Girls_CY'].value_counts()
# Out:
# Toilet_Girls_CY
# 1      479
# 2      277
# 3      109
# 0       92
# 4       75
# 5       25
# 6       17
# 7        9
# 10       9
# 12       9
# 8        8
# 14       3
# 11       2
# 16       1
# 22       1
# 26       1
# 23       1
# 27       1
# 18       1
# 123      1
# 20       1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['Toilet_Girls_CY'].value_counts(normalize = True)
dataset['Toilet_Girls_CY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['ToiletFunc_Boys_PY'].value_counts()
# Out:
# ToiletFunc_Boys_PY
# 1.0     525
# 2.0     285
# 3.0      94
# 0.0      57
# 4.0      55
# 6.0      22
# 5.0      19
# 10.0     10
# 7.0      10
# 8.0       9
# 12.0      5
# 14.0      2
# 15.0      1
# 18.0      1
# 27.0      1
# 26.0      1
# 29.0      1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['ToiletFunc_Boys_PY'].value_counts(normalize = True)
dataset['ToiletFunc_Boys_PY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['ToiletFunc_Boys_CY'].value_counts()
# Out:
# ToiletFunc_Boys_CY
# 1     448
# 2     244
# 0     185
# 3     102
# 4      58
# 5      22
# 6      20
# 7       9
# 12      8
# 10      7
# 8       6
# 9       2
# 15      2
# 11      2
# 20      2
# 18      1
# 14      1
# 27      1
# 26      1
# 29      1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['ToiletFunc_Boys_CY'].value_counts(normalize = True)
dataset['ToiletFunc_Boys_CY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['ToiletFunc_Boys_CY'].value_counts()
# Out:
# ToiletFunc_Boys_CY
# 1     448
# 2     244
# 0     185
# 3     102
# 4      58
# 5      22
# 6      20
# 7       9
# 12      8
# 10      7
# 8       6
# 9       2
# 15      2
# 11      2
# 20      2
# 18      1
# 14      1
# 27      1
# 26      1
# 29      1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['ToiletFunc_Boys_CY'].value_counts(normalize = True)
dataset['ToiletFunc_Boys_CY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['ToiletFunc_Girls_PY'].value_counts()
# Out:
# ToiletFunc_Girls_PY
# 1.0      529
# 2.0      286
# 3.0       87
# 4.0       67
# 0.0       48
# 5.0       20
# 6.0       16
# 10.0      11
# 8.0        9
# 7.0        8
# 12.0       5
# 14.0       3
# 18.0       2
# 23.0       1
# 11.0       1
# 123.0      1
# 9.0        1
# 27.0       1
# 26.0       1
# 22.0       1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['ToiletFunc_Girls_PY'].value_counts(normalize = True)
dataset['ToiletFunc_Girls_PY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['ToiletFunc_Girls_CY'].value_counts()
# Out:
# ToiletFunc_Girls_CY
# 1      438
# 2      255
# 0      188
# 3       89
# 4       66
# 5       24
# 6       17
# 10       9
# 8        8
# 7        8
# 12       8
# 11       2
# 14       2
# 16       1
# 22       1
# 26       1
# 23       1
# 27       1
# 18       1
# 123      1
# 20       1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['ToiletFunc_Girls_CY'].value_counts(normalize = True)
dataset['ToiletFunc_Girls_CY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['DrinkingWaterAvail_PY'].value_counts()
# Out:
# DrinkingWaterAvail_PY
# 1-Yes    1070
# 2-No       28
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['DrinkingWaterAvail_PY'].value_counts(normalize = True)
dataset['DrinkingWaterAvail_PY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['DrinkingWaterAvail_CY'].value_counts()
# Out:
# DrinkingWaterAvail_CY
# 1-Yes    1051
# 2-No       71
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['DrinkingWaterAvail_CY'].value_counts(normalize = True)
dataset['DrinkingWaterAvail_CY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['FuncDrinkingWater_PY'].value_counts()
# Out:
# FuncDrinkingWater_PY
# 1-Yes    738
# 2-No     360
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['FuncDrinkingWater_PY'].value_counts(normalize = True)
dataset['FuncDrinkingWater_PY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['FuncDrinkingWater_CY'].value_counts()
# Out:
# FuncDrinkingWater_CY
# 1-Yes    951
# 2-No     171
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['FuncDrinkingWater_CY'].value_counts(normalize = True)
dataset['FuncDrinkingWater_CY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['Electricity_PY'].value_counts()
# Out:
# Electricity_PY
# 1-Yes                        985
# 2-No                         109
# 3-Yes, but not Functional      4
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['Electricity_PY'].value_counts(normalize = True)
dataset['Electricity_PY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['Electricity_CY'].value_counts()
# Out:
# Electricity_CY
# 1-Yes                        1015
# 2-No                           93
# 3-Yes, but not Functional      14
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['Electricity_CY'].value_counts(normalize = True)
dataset['Electricity_CY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['Teacher_Tot_PY'].value_counts()
# Out:
# Teacher_Tot_PY
# 4.0     148
# 3.0     117
# 10.0     87
# 5.0      86
# 8.0      66
# 9.0      62
# 12.0     54
# 11.0     50
# 6.0      49
# 1.0      43
# 2.0      42
# 7.0      41
# 15.0     30
# 14.0     29
# 16.0     24
# 0.0      20
# 17.0     20
# 13.0     19
# 20.0     12
# 19.0     11
# 23.0     10
# 18.0     10
# 22.0      9
# 30.0      5
# 25.0      5
# 27.0      5
# 24.0      5
# 28.0      4
# 35.0      4
# 21.0      4
# 33.0      3
# 31.0      3
# 26.0      3
# 32.0      2
# 45.0      2
# 61.0      1
# 52.0      1
# 38.0      1
# 56.0      1
# 58.0      1
# 70.0      1
# 41.0      1
# 36.0      1
# 53.0      1
# 29.0      1
# 59.0      1
# 92.0      1
# 44.0      1
# 67.0      1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['Teacher_Tot_PY'].value_counts(normalize = True)
dataset['Teacher_Tot_PY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset['Teacher_Tot_CY'].value_counts()
# Out:
# Teacher_Tot_CY
# 3      161
# 4      102
# 0       98
# 2       79
# 10      77
# 8       68
# 11      53
# 9       52
# 5       52
# 7       47
# 12      45
# 6       39
# 14      37
# 15      32
# 13      27
# 17      19
# 16      14
# 18      11
# 19       9
# 20       9
# 25       8
# 31       7
# 21       7
# 32       6
# 27       5
# 1        5
# 29       5
# 23       5
# 22       5
# 30       4
# 24       4
# 37       3
# 26       2
# 39       2
# 33       2
# 38       2
# 56       2
# 44       1
# 61       1
# 69       1
# 72       1
# 45       1
# 101      1
# 40       1
# 55       1
# 53       1
# 36       1
# 64       1
# 34       1
# 43       1
# 28       1
# 35       1
# 98       1
# 63       1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(15,5))
dataset['Teacher_Tot_CY'].value_counts(normalize = True)
dataset['Teacher_Tot_CY'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green'])
plt.title('Class')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1122 entries, 0 to 1121
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Academic_Year          1122 non-null   object
#  1   UdiseCode              1122 non-null   int64
#  2   SchoolName             1122 non-null   object
#  3   SchoolManagement       1122 non-null   object
#  4   SchoolCategory         1122 non-null   object
#  5   BlockCode              1122 non-null   int64
#  6   SchoolType             1122 non-null   object
#  7   ClassRoom_Tot_PY       1098 non-null   float64
#  8   ClassRoom_Tot_CY       1122 non-null   int64
#  9   Toilet_Boys_PY         1098 non-null   float64
#  10  Toilet_Boys_CY         1122 non-null   int64
#  11  Toilet_Girls_PY        1098 non-null   float64
#  12  Toilet_Girls_CY        1122 non-null   int64
#  13  ToiletFunc_Boys_PY     1098 non-null   float64
# ...

# %%
sns.jointplot(x='SchoolName', y='ClassRoom_Tot_PY', data=dataset)

# %%
sns.jointplot(x='SchoolName', y='ClassRoom_Tot_CY', data=dataset)

# %%
sns.jointplot(x='SchoolName', y='Toilet_Boys_PY', data=dataset)

# %%
sns.jointplot(x='SchoolName', y='Toilet_Girls_PY', data=dataset)

# %%
sns.jointplot(x='SchoolName', y='ToiletFunc_Boys_PY', data=dataset)

# %%
sns.jointplot(x='SchoolName', y='DrinkingWaterAvail_PY', data=dataset)

# %%
sns.jointplot(x='SchoolName', y='FuncDrinkingWater_PY', data=dataset)

# %%
sns.jointplot(x='SchoolName', y='Electricity_PY', data=dataset)

# %%
sns.jointplot(x='SchoolName', y='Teacher_Tot_PY', data=dataset)

# %%
print(dataset.dtypes)
# Out:
# Academic_Year             object
# UdiseCode                  int64
# SchoolName                object
# SchoolManagement          object
# SchoolCategory            object
# BlockCode                  int64
# SchoolType                object
# ClassRoom_Tot_PY         float64
# ClassRoom_Tot_CY           int64
# Toilet_Boys_PY           float64
# Toilet_Boys_CY             int64
# Toilet_Girls_PY          float64
# Toilet_Girls_CY            int64
# ToiletFunc_Boys_PY       float64
# ToiletFunc_Boys_CY         int64
# ToiletFunc_Girls_PY      float64
# ToiletFunc_Girls_CY        int64
# DrinkingWaterAvail_PY     object
# DrinkingWaterAvail_CY     object
# FuncDrinkingWater_PY      object
# FuncDrinkingWater_CY      object
# Electricity_PY            object
# Electricity_CY            object
# Teacher_Tot_PY           float64
# Teacher_Tot_CY             int64
# dtype: object

# %%
print("NaNs:")
print(dataset.isna().any())
print("Infs:")
print(np.isinf(dataset).any())
# Out:
# NaNs:
# Academic_Year            False
# UdiseCode                False
# SchoolName               False
# SchoolManagement         False
# SchoolCategory           False
# BlockCode                False
# SchoolType               False
# ClassRoom_Tot_PY          True
# ClassRoom_Tot_CY         False
# Toilet_Boys_PY            True
# Toilet_Boys_CY           False
# Toilet_Girls_PY           True
# Toilet_Girls_CY          False
# ToiletFunc_Boys_PY        True
# ToiletFunc_Boys_CY       False
# ToiletFunc_Girls_PY       True
# ToiletFunc_Girls_CY      False
# DrinkingWaterAvail_PY     True
# DrinkingWaterAvail_CY    False
# FuncDrinkingWater_PY      True
# FuncDrinkingWater_CY     False
# Electricity_PY            True
# Electricity_CY           False
# Teacher_Tot_PY            True
# Teacher_Tot_CY           False
# dtype: bool
# Infs:
# ---------------------------------------------------------------------------
# ...

# %%
dataset_cleaned = dataset.replace([np.inf, -np.inf], np.nan).dropna()

# %%
print(dataset_cleaned)
# Out:
#      Academic_Year    UdiseCode  \
# 0          2022-23  23320400102
# 1          2022-23  23320400105
# 2          2022-23  23320400106
# 3          2022-23  23320400107
# 4          2022-23  23320400108
# ...            ...          ...
# 1112       2022-23  23320404602
# 1116       2022-23  23320404801
# 1117       2022-23  23320404802
# 1118       2022-23  23320404803
# 1119       2022-23  23320404804
#
#                                              SchoolName  \
# 0                                    GOVT MS KHANU GAON
# 1     PVT MS (1-8) ANJORA MIDDLE SCHOOL, KHANUGAON (...
# 2     MADARSA (RE) PS (1-5) NEW HINA DEENI KHANUGAON...
# 3     MADARSA (RE) PS (1-5) AL NISA,HAMEEDULLAH NAGA...
# 4     MADARSA (RE) MS (1-8) TAYYAB,8-NOOR-US-SABHA R...
# ...                                                 ...
# 1112          PVT MS KANTI DEVI MEMORIYAL PUBLIC SCHOOL
# 1116  PVT MS (1-8) BASE PRIDE CO-ED SCHOOL 41 KHEJAD...
# 1117  PVT MS (1-8) VASANT VALLEY SCHOOL, NEAR GOVT H...
# ...

# %%
dataset.head()
# Out:
#   Academic_Year    UdiseCode  \
# 0       2022-23  23320400102
# 1       2022-23  23320400105
# 2       2022-23  23320400106
# 3       2022-23  23320400107
# 4       2022-23  23320400108
#
#                                           SchoolName  \
# 0                                 GOVT MS KHANU GAON
# 1  PVT MS (1-8) ANJORA MIDDLE SCHOOL, KHANUGAON (...
# 2  MADARSA (RE) PS (1-5) NEW HINA DEENI KHANUGAON...
# 3  MADARSA (RE) PS (1-5) AL NISA,HAMEEDULLAH NAGA...
# 4  MADARSA (RE) MS (1-8) TAYYAB,8-NOOR-US-SABHA R...
#
#                  SchoolManagement                  SchoolCategory  BlockCode  \
# 0       1-Department of Education  2 - Primary with Upper Primary     233204
# 1  5-Private Unaided (Recognized)  2 - Primary with Upper Primary     233204
# 2           97-Madarsa recognized                     1 - Primary     233204
# 3           97-Madarsa recognized                     1 - Primary     233204
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1122 entries, 0 to 1121
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Academic_Year          1122 non-null   object
#  1   UdiseCode              1122 non-null   int64
#  2   SchoolName             1122 non-null   object
#  3   SchoolManagement       1122 non-null   object
#  4   SchoolCategory         1122 non-null   object
#  5   BlockCode              1122 non-null   int64
#  6   SchoolType             1122 non-null   object
#  7   ClassRoom_Tot_PY       1098 non-null   float64
#  8   ClassRoom_Tot_CY       1122 non-null   int64
#  9   Toilet_Boys_PY         1098 non-null   float64
#  10  Toilet_Boys_CY         1122 non-null   int64
#  11  Toilet_Girls_PY        1098 non-null   float64
#  12  Toilet_Girls_CY        1122 non-null   int64
#  13  ToiletFunc_Boys_PY     1098 non-null   float64
# ...

# %%
print(dataset_cleaned)
# Out:
#      Academic_Year    UdiseCode  \
# 0          2022-23  23320400102
# 1          2022-23  23320400105
# 2          2022-23  23320400106
# 3          2022-23  23320400107
# 4          2022-23  23320400108
# ...            ...          ...
# 1112       2022-23  23320404602
# 1116       2022-23  23320404801
# 1117       2022-23  23320404802
# 1118       2022-23  23320404803
# 1119       2022-23  23320404804
#
#                                              SchoolName  \
# 0                                    GOVT MS KHANU GAON
# 1     PVT MS (1-8) ANJORA MIDDLE SCHOOL, KHANUGAON (...
# 2     MADARSA (RE) PS (1-5) NEW HINA DEENI KHANUGAON...
# 3     MADARSA (RE) PS (1-5) AL NISA,HAMEEDULLAH NAGA...
# 4     MADARSA (RE) MS (1-8) TAYYAB,8-NOOR-US-SABHA R...
# ...                                                 ...
# 1112          PVT MS KANTI DEVI MEMORIYAL PUBLIC SCHOOL
# 1116  PVT MS (1-8) BASE PRIDE CO-ED SCHOOL 41 KHEJAD...
# 1117  PVT MS (1-8) VASANT VALLEY SCHOOL, NEAR GOVT H...
# ...

# %%
import statsmodels.api as sn

# %%
X = sn.add_constant(dataset['ClassRoom_Tot_PY'])

# %%
lm = sn.OLS(dataset['ClassRoom_Tot_CY'], X).fit()
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 lm = sn.OLS(dataset['ClassRoom_Tot_CY'], X).fit()
#
# File ~\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:922, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     919     msg = ("Weights are not supported in OLS and will be ignored"
#     920            "An exception will be raised in the next version.")
#     921     warnings.warn(msg, ValueWarning)
# --> 922 super(OLS, self).__init__(endog, exog, missing=missing,
#     923                           hasconst=hasconst, **kwargs)
#     924 if "weights" in self._init_keys:
#     925     self._init_keys.remove("weights")
#
# File ~\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:748, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     746 else:
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
y = dataset['BlockCode']

# %%
X = dataset[['ClassRoom_Tot_PY']]

# %%
lm2 = LinearRegression()

# %%
from sklearn.svm import SVR

# %%
from sklearn.ensemble import BaggingRegressor

# %%
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples=100, n_features=4,
                       n_informative=2, n_targets=1,
                      random_state=0, shuffle=False)

# %%
regr = BaggingRegressor(estimator=SVR(),n_estimators=10, random_state=0).fit(X, y)

# %%
regr.predict([[0, 0, 0, 0]])
# Out:
# array([-2.87202411])

# %%
lm2.fit(X,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_, lm2.coef_)
# Out:
# -1.7763568394002505e-15 [ 2.04923687e+01  3.41698115e+01 -3.25963402e-15  1.82302801e-15]

# %%
help(lm2)
# Out:
# Help on LinearRegression in module sklearn.linear_model._base object:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(*, fit_intercept=True, copy_X=True, n_jobs=None, positive=False)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  copy_X : bool, default=True
#  |      If True, X will be copied; else, it may be overwritten.
#  |
#  |  n_jobs : int, default=None
# ...

# %%
lm2.predict(X)
# Out:
# array([ 49.82290745,   4.87728597,  11.91487464,  19.75307803,
#         23.60700003, -29.98278439,  -3.18275233,  81.61798896,
#        -85.87627478,  66.296663  , -70.00907918, -25.41289672,
#        -40.341885  , -50.80958638,  11.69850317, -26.06617118,
#        -10.09289693, -16.81772822, -18.84474658, -37.62388016,
#          6.90439112,  95.27998841,  14.08815923,  37.63961941,
#         61.23802841,  -7.46245465,  42.37309217,  89.99454831,
#         47.61800511,  14.11477091, -29.85246699, -19.3463247 ,
#         27.69980617, -12.73102933,   4.69818239, -15.54546881,
#         81.10896741, -42.73831876, -43.50103947, -13.81361736,
#         55.72588193,   3.73964726,  35.17541383,  -4.68693299,
#        -40.02555297, -54.23600024, -41.92953467,  37.56912025,
#        -40.71853261,  43.95479823, -15.74495171, -42.13327197,
#          2.38253778,   0.17626991,  12.60675473, -31.41170946,
#        -29.41293009, -20.37016177,   3.09183413, -40.10546979,
# ...

# %%
sns.jointplot(x = dataset['ClassRoom_Tot_PY'], y = dataset['BlockCode'], data = dataset, kind = 'reg')

# %%
y = dataset['BlockCode']

# %%
X = dataset[['ClassRoom_Tot_CY']]

# %%
lm3 = LinearRegression()

# %%
lm3.fit(X, y)
# Out:
# LinearRegression()

# %%
print(lm3.intercept_, lm3.coef_)
# Out:
# 233204.0 [-0.]

# %%
lm3.predict(X)
# Out:
# array([233204., 233204., 233204., ..., 233204., 233204., 233204.])

# %%
sns.jointplot(x = dataset['ClassRoom_Tot_CY'], y = dataset['BlockCode'], data = dataset, kind = 'reg')

# %%
y = dataset['BlockCode']

# %%
x = dataset[['Toilet_Boys_PY']]

# %%
lm4 = LinearRegression()

# %%
x, y = make_regression(n_samples=100, n_features=4,
                       n_informative=2, n_targets=1,
                      random_state=0, shuffle=False)

# %%
regr = BaggingRegressor(estimator=SVR(),n_estimators=10, random_state=0).fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 regr = BaggingRegressor(estimator=SVR(),n_estimators=10, random_state=0).fit(X, y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_bagging.py:330, in BaseBagging.fit(self, X, y, sample_weight)
#     307 """Build a Bagging ensemble of estimators from the training set (X, y).
#     308
#     309 Parameters
#    (...)
#     327     Fitted estimator.
#     328 """
# ...

# %%
lm4.fit(x,y)
# Out:
# LinearRegression()

# %%
lm4.predict(x)
# Out:
# array([ 49.82290745,   4.87728597,  11.91487464,  19.75307803,
#         23.60700003, -29.98278439,  -3.18275233,  81.61798896,
#        -85.87627478,  66.296663  , -70.00907918, -25.41289672,
#        -40.341885  , -50.80958638,  11.69850317, -26.06617118,
#        -10.09289693, -16.81772822, -18.84474658, -37.62388016,
#          6.90439112,  95.27998841,  14.08815923,  37.63961941,
#         61.23802841,  -7.46245465,  42.37309217,  89.99454831,
#         47.61800511,  14.11477091, -29.85246699, -19.3463247 ,
#         27.69980617, -12.73102933,   4.69818239, -15.54546881,
#         81.10896741, -42.73831876, -43.50103947, -13.81361736,
#         55.72588193,   3.73964726,  35.17541383,  -4.68693299,
#        -40.02555297, -54.23600024, -41.92953467,  37.56912025,
#        -40.71853261,  43.95479823, -15.74495171, -42.13327197,
#          2.38253778,   0.17626991,  12.60675473, -31.41170946,
#        -29.41293009, -20.37016177,   3.09183413, -40.10546979,
# ...

# %%
sns.jointplot(x = dataset['Toilet_Boys_PY'], y = dataset['BlockCode'], data = dataset, kind = 'reg')

# %%
sns.jointplot(x = dataset['Toilet_Girls_PY'], y = dataset['BlockCode'], data = dataset, kind = 'reg')

# %%
X = dataset[['Toilet_Girls_PY']]

# %%
y = dataset['BlockCode']

# %%
X, y = make_regression(n_samples=100, n_features=4,
                       n_informative=2, n_targets=1,
                      random_state=0, shuffle=False)

# %%
lm5 = LinearRegression()

# %%
lm5.fit(X,y)
# Out:
# LinearRegression()

# %%
lm5.predict(X)
# Out:
# array([ 49.82290745,   4.87728597,  11.91487464,  19.75307803,
#         23.60700003, -29.98278439,  -3.18275233,  81.61798896,
#        -85.87627478,  66.296663  , -70.00907918, -25.41289672,
#        -40.341885  , -50.80958638,  11.69850317, -26.06617118,
#        -10.09289693, -16.81772822, -18.84474658, -37.62388016,
#          6.90439112,  95.27998841,  14.08815923,  37.63961941,
#         61.23802841,  -7.46245465,  42.37309217,  89.99454831,
#         47.61800511,  14.11477091, -29.85246699, -19.3463247 ,
#         27.69980617, -12.73102933,   4.69818239, -15.54546881,
#         81.10896741, -42.73831876, -43.50103947, -13.81361736,
#         55.72588193,   3.73964726,  35.17541383,  -4.68693299,
#        -40.02555297, -54.23600024, -41.92953467,  37.56912025,
#        -40.71853261,  43.95479823, -15.74495171, -42.13327197,
#          2.38253778,   0.17626991,  12.60675473, -31.41170946,
#        -29.41293009, -20.37016177,   3.09183413, -40.10546979,
# ...

# %%
sns.jointplot(x = dataset['Toilet_Girls_CY'], y = dataset['BlockCode'], data = dataset, kind = 'reg')

# %%
print(lm5.intercept_, lm5.coef_)
# Out:
# -1.7763568394002505e-15 [ 2.04923687e+01  3.41698115e+01 -3.25963402e-15  1.82302801e-15]

# %%
sns.jointplot(x = dataset['DrinkingWaterAvail_PY'], y = dataset['BlockCode'], data = dataset, kind = 'reg')
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 sns.jointplot(x = dataset['DrinkingWaterAvail_PY'], y = dataset['BlockCode'], data = dataset, kind = 'reg')
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2324, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2321     grid.plot_marginals(histplot, **marginal_kws)
#    2323     joint_kws.setdefault("color", color)
# -> 2324     grid.plot_joint(regplot, **joint_kws)
#    2326 elif kind.startswith("resid"):
#    2328     joint_kws.setdefault("color", color)
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1826, in JointGrid.plot_joint(self, func, **kwargs)
#    1823     self._inject_kwargs(func, kwargs, self._hue_params)
# ...

# %%
sns.jointplot(x = dataset['Teacher_Tot_CY'], y = dataset['BlockCode'], data = dataset, kind = 'reg')

# %%
sns.jointplot(x = dataset['Electricity_PY'], y = dataset['BlockCode'], data = dataset, kind = 'reg')
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 sns.jointplot(x = dataset['Electricity_PY'], y = dataset['BlockCode'], data = dataset, kind = 'reg')
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2324, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2321     grid.plot_marginals(histplot, **marginal_kws)
#    2323     joint_kws.setdefault("color", color)
# -> 2324     grid.plot_joint(regplot, **joint_kws)
#    2326 elif kind.startswith("resid"):
#    2328     joint_kws.setdefault("color", color)
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1826, in JointGrid.plot_joint(self, func, **kwargs)
#    1823     self._inject_kwargs(func, kwargs, self._hue_params)
# ...

# %%
sns.jointplot(x = dataset['Teacher_Tot_PY'], y = dataset['BlockCode'], data = dataset, kind = 'reg')

# %%
y_multi = dataset['BlockCode']

# %%
y_multi.head()
# Out:
# 0    233204
# 1    233204
# 2    233204
# 3    233204
# 4    233204
# Name: BlockCode, dtype: int64

# %%
X_multi = dataset[['ClassRoom_Tot_PY']]

# %%
X_multi_cons = sn.add_constant(X_multi)

# %%
X_multi_cons.head()
# Out:
#    const  ClassRoom_Tot_PY
# 0    1.0               9.0
# 1    1.0               5.0
# 2    1.0               4.0
# 3    1.0               3.0
# 4    1.0               5.0

# %%
X_multi_cons, y_multi = make_regression(n_samples=100, n_features=4,
                       n_informative=2, n_targets=1,
                      random_state=0, shuffle=False)

# %%
regr = BaggingRegressor(estimator=SVR(),n_estimators=10, random_state=0).fit(X_multi_cons, y_multi)

# %%
lm_multi = sn.OLS(y_multi, X_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          1.611e+31
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        01:09:07   Log-Likelihood:                          2926.5
# No. Observations:                 100   AIC:                                     -5845.
# Df Residuals:                      96   BIC:                                     -5835.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
y_multi = dataset['BlockCode']

# %%
X_multi = dataset[['Teacher_Tot_PY']]

# %%
X_multi, y_multi = make_regression(n_samples=100, n_features=4,
                       n_informative=2, n_targets=1,
                      random_state=0, shuffle=False)

# %%
regr = BaggingRegressor(estimator=SVR(),n_estimators=10, random_state=0).fit(X_multi, y_multi)

# %%
lm_multi = sn.OLS(y_multi, X_multi).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          1.611e+31
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        01:09:11   Log-Likelihood:                          2926.5
# No. Observations:                 100   AIC:                                     -5845.
# Df Residuals:                      96   BIC:                                     -5835.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
lm = LinearRegression()

# %%
lm.fit(X_multi, y_multi)
# Out:
# LinearRegression()

# %%
print(lm.intercept_, lm.coef_)
# Out:
# -1.7763568394002505e-15 [ 2.04923687e+01  3.41698115e+01 -3.25963402e-15  1.82302801e-15]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_multi, y_multi, test_size = 0.2, random_state = 0)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (80, 4) (20, 4) (80,) (20,)

# %%
lm_a = LinearRegression()

# %%
lm_a.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_test_a = lm_a.predict(X_test)

# %%
y_train_a = lm_a.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score?

# %%
r2_score(y_test, y_test_a)
# Out:
# 1.0

# %%
r2_score(y_train, y_train_a)
# Out:
# 1.0

# %%
y_multi = dataset['BlockCode']

# %%
X_multi = dataset[['Teacher_Tot_CY']]

# %%
X_multi_cons = sn.add_constant(X_multi)

# %%
X_multi_cons.head()
# Out:
#    const  Teacher_Tot_CY
# 0    1.0               8
# 1    1.0               9
# 2    1.0               2
# 3    1.0               4
# 4    1.0               4

# %%
lm = LinearRegression()

# %%
regr = BaggingRegressor(estimator=SVR(),n_estimators=10, random_state=0).fit(X_multi, y_multi)

# %%
lm_multi = sn.OLS(y_multi, X_multi).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              BlockCode   R-squared (uncentered):                   0.470
# Model:                            OLS   Adj. R-squared (uncentered):              0.470
# Method:                 Least Squares   F-statistic:                              994.6
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):                   8.70e-157
# Time:                        01:10:22   Log-Likelihood:                         -15103.
# No. Observations:                1122   AIC:                                  3.021e+04
# Df Residuals:                    1121   BIC:                                  3.021e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
print(lm.intercept_, lm.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 print(lm.intercept_, lm.coef_)
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_multi, y_multi, test_size = 0.2, random_state = 0)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (897, 1) (225, 1) (897,) (225,)

# %%
lm_a = LinearRegression()

# %%
lm_a.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_test_a = lm_a.predict(X_test)

# %%
y_train_a = lm_a.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score?

# %%
r2_score(y_test, y_test_a)
# Out:
# 1.0

# %%
r2_score(y_train, y_train_a)
# Out:
# 1.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1122 entries, 0 to 1121
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Academic_Year          1122 non-null   object
#  1   UdiseCode              1122 non-null   int64
#  2   SchoolName             1122 non-null   object
#  3   SchoolManagement       1122 non-null   object
#  4   SchoolCategory         1122 non-null   object
#  5   BlockCode              1122 non-null   int64
#  6   SchoolType             1122 non-null   object
#  7   ClassRoom_Tot_PY       1098 non-null   float64
#  8   ClassRoom_Tot_CY       1122 non-null   int64
#  9   Toilet_Boys_PY         1098 non-null   float64
#  10  Toilet_Boys_CY         1122 non-null   int64
#  11  Toilet_Girls_PY        1098 non-null   float64
#  12  Toilet_Girls_CY        1122 non-null   int64
#  13  ToiletFunc_Boys_PY     1098 non-null   float64
# ...

# %%
y_multi = dataset['BlockCode']

# %%
X_multi = dataset[['ToiletFunc_Girls_PY']]

# %%
X_multi_cons = sn.add_constant(X_multi)

# %%
X_multi_cons.head()
# Out:
#    const  ToiletFunc_Girls_PY
# 0    1.0                  2.0
# 1    1.0                  4.0
# 2    1.0                  1.0
# 3    1.0                  1.0
# 4    1.0                  1.0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_multi, y_multi, test_size = 0.2, random_state = 0)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (897, 1) (225, 1) (897,) (225,)

# %%
lm = LinearRegression()

# %%
from sklearn.datasets import load_iris
>>> from sklearn.impute import SimpleImputer, MissingIndicator
>>> from sklearn.model_selection import train_test_split
>>> from sklearn.pipeline import FeatureUnion, make_pipeline
>>> from sklearn.tree import DecisionTreeClassifier
>>> X, y = load_iris(return_X_y=True)
>>> mask = np.random.randint(0, 2, size=X.shape).astype(bool)
>>> X[mask] = np.nan
>>> X_train, X_test, y_train, _ = train_test_split(X, y, test_size=100,
...                                                random_state=0)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1122 entries, 0 to 1121
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Academic_Year          1122 non-null   object
#  1   UdiseCode              1122 non-null   int64
#  2   SchoolName             1122 non-null   object
#  3   SchoolManagement       1122 non-null   object
#  4   SchoolCategory         1122 non-null   object
#  5   BlockCode              1122 non-null   int64
#  6   SchoolType             1122 non-null   object
#  7   ClassRoom_Tot_PY       1098 non-null   float64
#  8   ClassRoom_Tot_CY       1122 non-null   int64
#  9   Toilet_Boys_PY         1098 non-null   float64
#  10  Toilet_Boys_CY         1122 non-null   int64
#  11  Toilet_Girls_PY        1098 non-null   float64
#  12  Toilet_Girls_CY        1122 non-null   int64
#  13  ToiletFunc_Boys_PY     1098 non-null   float64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier

# %%
imputer = SimpleImputer(strategy='mean')

# %%
 import numpy as np
from sklearn.impute import SimpleImputer
 imp = SimpleImputer(missing_values=np.nan, strategy='mean')
 imp.fit([[1, 2], [np.nan, 3], [7, 6]])
SimpleImputer()
# Out:
# SimpleImputer()

# %%
# split dataset
X = dataset.iloc[:, 7:16]
y = dataset.iloc[:, 16]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)

# %%
# Create a pipeline with the imputer and the classifier
pipeline = Pipeline([
    ('imputer', imputer),
    ('classifier', KNeighborsClassifier())
])

# %%
# Fit the pipeline on your data
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()),
#                 ('classifier', KNeighborsClassifier())])

# %%
# Drop rows with NaN values
X_clean = X.dropna()
y_clean = y[X.index.isin(X_clean.index)]

# %%
knn_classifier.fit(X_clean, y_clean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 knn_classifier.fit(X_clean, y_clean)
#
# NameError: name 'knn_classifier' is not defined

# %%
#Feature Scaling
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
import math
math.sqrt(len(y_train))
# Out:
# 29.949958263743873

# %%
import math
math.sqrt(len(y_test))
# Out:
# 15.0

# %%
#define model
classifier = KNeighborsClassifier(n_neighbors=11, p=2, metric='euclidean')

# %%
#fit model
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[186], line 2
#       1 #fit model
# ----> 2 classifier.fit(X_train, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:228, in KNeighborsClassifier.fit(self, X, y)
#     206 @_fit_context(
#     207     # KNeighborsClassifier.metric is not validated yet
#     208     prefer_skip_nested_validation=False
#     209 )
#     210 def fit(self, X, y):
# ...
